# %%
import psycopg2
import datetime
import numpy as np
import pandas as pd
from itertools import islice

import math
import sklearn as sk
import xgboost as xg
import statsmodels.tsa.stattools as sm_tools
import statsmodels.tsa.arima_model as stats_arima

import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from mpl_toolkits.mplot3d import Axes3D
from pandas.plotting import register_matplotlib_converters

from finance.utilities import utils
from finance.data_science.utilities import financial_utils, time_series_utils

# %%
register_matplotlib_converters()

# %matplotlib notebook
# %matplotlib inline

# %% [markdown]
# # Options

# %%
query = """
    with sub as (
        select *, dense_rank() over (partition by symbol order by file_datetime) as dr
        from td.options
        where symbol = 'BA' and file_datetime::date = '2020-03-27'
        )
    select *
    from sub
    where dr = 1
    """

options = utils.query_db(query=query)

# %%
options.head(3).T
# Out:
#                                                  0                       1  \
# symbol                                          BA                      BA
# volatility                                      29                      29
# n_contracts                                   3298                    3298
# interest_rate                              2.42788                 2.42788
# put_call                                       PUT                     PUT
# description                 BA Jun 18 2021 170 Put  BA Jun 18 2021 350 Put
# exchange_name                                  OPR                     OPR
# bid                                           46.1                   175.5
# ask                                           50.5                   179.8
# last                                         48.99                   179.1
# mark                                          48.3                  177.65
# bid_size                                        20                      10
# ask_size                                         3                      20
# bid_ask_size                                  20X3                   10X20
# last_size                                        0                       0
# high_price                                   49.63                   179.1
# low_price                                     48.8                   179.1
# open_price                                       0                       0
# close_price                                  57.31                  197.51
# total_volume                                    11                       1
# trade_date                                    None                    None
# trade_time_in_long                 1585244788636.0         1585244648136.0
# quote_time_in_long                 1585252799463.0         1585252799823.0
# net_change                                   -8.32                  -18.41
# delta                                       -0.309                  -0.738
# gamma                                        0.002                   0.002
# theta                                       -0.054                  -0.029
# vega                                          0.68                    0.48
# rho                                         -1.296                  -4.181
# open_interest                                   75                     181
# time_value                                   48.99                    9.65
# theoretical_option_value                      48.3                  177.65
# theoretical_volatility                          29                      29
# option_deliverable_list                       None                    None
# strike_price                                   170                     350
# expiration_date                    1624046400000.0         1624046400000.0
# days_to_expiration                             449                     449
# expiration_type                                  R                       R
# last_trading_day                   1624060800000.0         1624060800000.0
# multiplier                                     100                     100
# settlement_type
# deliverable_note                              None                    None
# is_index_option                               None                    None
# percent_change                              -14.52                   -9.32
# mark_change                                  -9.01                  -19.86
# mark_percent_change                         -15.72                  -10.05
# non_standard                                 False                   False
# mini                                         False                   False
# in_the_money                                 False                    True
# expiration_date_from_epoch     2021-06-18 20:00:00     2021-06-18 20:00:00
# strike                                         170                     350
# strike_date                    2021-06-18 00:00:00     2021-06-18 00:00:00
# days_to_expiration_date                        449                     449
# file_datetime                  2020-03-27 00:58:56     2020-03-27 00:58:56
# ingest_datetime                2020-04-23 01:28:28     2020-04-23 01:28:28
# dr                                               1                       1
#
#                                                  2
# symbol                                          BA
# volatility                                      29
# n_contracts                                   3298
# interest_rate                              2.42788
# put_call                                       PUT
# description                 BA Jun 18 2021 345 Put
# exchange_name                                  OPR
# bid                                            171
# ask                                            176
# last                                           246
# mark                                         173.5
# bid_size                                         3
# ask_size                                         3
# bid_ask_size                                   3X3
# last_size                                        0
# high_price                                       0
# low_price                                        0
# open_price                                       0
# close_price                                 193.01
# total_volume                                     0
# trade_date                                    None
# trade_time_in_long                 1584985414118.0
# quote_time_in_long                 1585252799460.0
# net_change                                   52.99
# delta                                       -0.727
# gamma                                        0.002
# theta                                       -0.031
# vega                                           0.5
# rho                                         -4.104
# open_interest                                   33
# time_value                                   81.55
# theoretical_option_value                     173.5
# theoretical_volatility                          29
# option_deliverable_list                       None
# strike_price                                   345
# expiration_date                    1624046400000.0
# days_to_expiration                             449
# expiration_type                                  R
# last_trading_day                   1624060800000.0
# multiplier                                     100
# settlement_type
# deliverable_note                              None
# is_index_option                               None
# percent_change                               27.46
# mark_change                                 -19.51
# mark_percent_change                         -10.11
# non_standard                                 False
# mini                                         False
# in_the_money                                  True
# expiration_date_from_epoch     2021-06-18 20:00:00
# strike                                         345
# strike_date                    2021-06-18 00:00:00
# days_to_expiration_date                        449
# file_datetime                  2020-03-27 00:58:56
# ingest_datetime                2020-04-23 01:28:28
# dr                                               1

# %% [markdown]
# ### Black scholes

# %%
option = financial_utils.BlackScholes(
    current_stock_price=380,
    strike_price=385,
    risk_free_rate=1.025,
    days_to_maturity=160,
    volatility=1.15,
    call_put='call'
)

# %%
print('Theoretical option price: $' + str(round(option.option_price, 2)))
# Out:
# Theoretical option price: $112.4

# %% [markdown]
# ### Greeks

# %%
deltas = option.get_greek(greek='delta', steps=30)
plt.plot(deltas, marker='.')
plt.show()

# %%
ros = option.get_greek(greek='ro', steps=40)
plt.plot(ros, marker='.')
plt.show()

# %%
thetas = option.get_greek('theta', steps=90)
plt.plot(thetas, marker='.')
plt.show()

# %%
vegas = option.get_greek(greek='vega', steps=30)
plt.plot(vegas, marker='.')
plt.show()

# %% [markdown]
# ### Implied volatility

# %%
imp_vols = []
current_stock_price = 434.42
risk_free_rate=1.025
volatility=.15
opts = options[(options['put_call'].str.lower()=='call') & (options['total_volume']>0)].sort_values(by=['strike'])
for idw, row in opts.iterrows():
    imp_vol = financial_utils.BlackScholes(
        current_option_price=row['close_price'],
        current_stock_price=current_stock_price,
        strike_price=row['strike'],
        risk_free_rate=risk_free_rate,
        days_to_maturity=row['days_to_expiration_date'],
        volatility=volatility,
        call_put=row['put_call'].lower()
    ).implied_volatility
    imp_vols.append(imp_vol)

# %%
imp_vols = pd.DataFrame(imp_vols)
plt.figure()
plt.title('Implied Vol')
plt.plot(imp_vols)
plt.show()

# %%
df = options[(options['file_datetime'].dt.date == options['file_datetime'].min().date())
             & (options['total_volume'] > 0)
             & (options['put_call'].str.lower() == 'call')
             & (options['strike'].between(200, 500))
             & (options['days_to_expiration_date'].between(10, 300))
            ].copy()

# %%
df = options[(options['file_datetime'].dt.date == options['file_datetime'].min().date())
             & (options['total_volume'] > 0)
             & (options['put_call'].str.lower() == 'call')
             & (options['strike'].between(200, 500))
             & (options['days_to_expiration_date'].between(10, 300))
            ].copy()

# %%
current_stock_price = 380
df['implied_volatility'] = df.apply(lambda option: 
                                    financial_utils.BlackScholes(current_option_price=option['close_price'],
                                                                 current_stock_price=current_stock_price,
                                                                 strike_price=option['strike'],
                                                                 risk_free_rate=risk_free_rate,
                                                                 days_to_maturity=option['days_to_expiration_date'],
                                                                 call_put=option['put_call'].lower()
                                                                ).implied_volatility,
                                    axis=1)
df = df.sort_values(by='implied_volatility').iloc[5:-5]

# %%
fig = plt.figure()
ax = Axes3D(fig)

zline = df['implied_volatility']
xline = df['days_to_expiration_date']
yline = df['strike']

ax.scatter(xline, yline, zline, 'gray')
fig.show()
