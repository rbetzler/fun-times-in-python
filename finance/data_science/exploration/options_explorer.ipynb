# %%
import psycopg2
import datetime
import numpy as np
import pandas as pd
from itertools import islice

import math
import sklearn as sk
import xgboost as xg
import statsmodels.tsa.stattools as sm_tools
import statsmodels.tsa.arima_model as stats_arima

import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from mpl_toolkits.mplot3d import Axes3D
from pandas.plotting import register_matplotlib_converters

from finance.utilities import utils, financial_utils, time_series_utils
# Out:
# ImportErrorTraceback (most recent call last)
# <ipython-input-4-a79c81dd6b6d> in <module>()
#       7 import math
#       8 # import sklearn as sk
# ----> 9 import xgboost as xg
#      10 import statsmodels.tsa.stattools as sm_tools
#      11 import statsmodels.tsa.arima_model as stats_arima
#
# ImportError: No module named xgboost

# %%
register_matplotlib_converters()

# %matplotlib notebook
# %matplotlib inline

# %% [markdown]
# # Options

# %%
query = """
    select *
    from td.options
    where symbol = 'BA'
    """

options = utils.query_db(db_connection=utils.DW_STOCKS_JUPYTER, query=query)

# %%
options.head(1).T
# Out:
#                                                  0
# symbol                                          BA
# volatility                                      29
# n_contracts                                   1782
# interest_rate                              2.42788
# put_call                                       PUT
# description                 BA Jan 17 2020 540 Put
# exchange_name                                  OPR
# bid                                         155.25
# ask                                          156.3
# last                                        206.05
# mark                                        155.78
# bid_size                                        10
# ask_size                                        10
# bid_ask_size                                 10X10
# last_size                                        0
# high_price                                       0
# low_price                                        0
# open_price                                       0
# close_price                                 153.98
# total_volume                                     0
# trade_date                                    None
# trade_time_in_long                 1565291922336.0
# quote_time_in_long                 1568923199844.0
# net_change                                   52.07
# delta                                           -1
# gamma                                            0
# theta                                            0
# vega                                         7.918
# rho                                              0
# open_interest                                    0
# time_value                                   50.49
# theoretical_option_value                   156.325
# theoretical_volatility                          29
# option_deliverable_list                       None
# strike_price                                   540
# expiration_date                    1579316400000.0
# days_to_expiration                             120
# expiration_type                                  R
# last_trading_day                   1579237200000.0
# multiplier                                     100
# settlement_type
# deliverable_note                              None
# is_index_option                               None
# percent_change                               33.81
# mark_change                                   1.79
# mark_percent_change                           1.16
# non_standard                                 False
# mini                                         False
# in_the_money                                  True
# expiration_date_from_epoch     2020-01-18 03:00:00
# strike                                         540
# strike_date                    2020-01-17 00:00:00
# days_to_expiration_date                        120
# file_datetime                  2019-09-20 03:48:48
# ingest_datetime                2019-09-22 02:59:39
# rn                                               1

# %% [markdown]
# ### Black scholes

# %%
option = financial_utils.BlackScholes(
    current_stock_price=380,
    strike_price=385,
    risk_free_rate=1.025,
    days_to_maturity=160,
    volatility=1.15,
    call_put='call'
)

# %%
print('Theoretical option price: $' + str(round(option.option_price, 2)))
# Out:
# Theoretical option price: $112.4

# %% [markdown]
# ### Greeks

# %%
deltas = option.get_greek(greek='delta', steps=30)
plt.plot(deltas, marker='.')
plt.show()

# %%
ros = option.get_greek(greek='ro', steps=40)
plt.plot(ros, marker='.')
plt.show()

# %%
thetas = option.get_greek('theta', steps=90)
plt.plot(thetas, marker='.')
plt.show()

# %%
vegas = option.get_greek(greek='vega', steps=30)
plt.plot(vegas, marker='.')
plt.show()

# %% [markdown]
# ### Implied volatility

# %%
imp_vols = []
current_stock_price = 354.42
risk_free_rate=1.025
volatility=.5
opts = options[(options['days_to_expiration']==120) 
               & (options['put_call'].str.lower()=='call') 
               & (options['total_volume']>0)]
for idw, row in opts.iterrows():
    imp_vol = financial_utils.BlackScholes(
        current_option_price=row['close_price'],
        current_stock_price=current_stock_price,
        strike_price=row['strike'],
        risk_free_rate=risk_free_rate,
        days_to_maturity=row['days_to_expiration_date'],
        volatility=volatility,
        call_put=row['put_call'].lower()
    ).implied_volatility
    imp_vols.append(imp_vol)

# %%
imp_vols = pd.DataFrame(imp_vols)
plt.figure()
plt.title('Implied Vol')
plt.plot(imp_vols)
plt.show()

# %%
df = options[(options['file_datetime'].dt.date == options['file_datetime'].min().date())
             & (options['total_volume'] > 0)
             & (options['put_call'].str.lower() == 'call')
             & (options['strike'].between(200, 500))
             & (options['days_to_expiration_date'].between(10, 300))
            ].copy()

# %%
df = options[(options['file_datetime'].dt.date == options['file_datetime'].min().date())
             & (options['total_volume'] > 0)
             & (options['put_call'].str.lower() == 'call')
             & (options['strike'].between(200, 500))
             & (options['days_to_expiration_date'].between(10, 300))
            ].copy()

# %%
current_stock_price = 380
df['implied_volatility'] = df.apply(lambda option: 
                                    financial_utils.BlackScholes(current_option_price=option['close_price'],
                                                                 current_stock_price=current_stock_price,
                                                                 strike_price=option['strike'],
                                                                 risk_free_rate=risk_free_rate,
                                                                 days_to_maturity=option['days_to_expiration_date'],
                                                                 call_put=option['put_call'].lower()
                                                                ).implied_volatility,
                                    axis=1)
df = df.sort_values(by='implied_volatility').iloc[5:-5]

# %%
fig = plt.figure()
ax = Axes3D(fig)

zline = df['implied_volatility']
xline = df['days_to_expiration_date']
yline = df['strike']

ax.scatter(xline, yline, zline, 'gray')
fig.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
