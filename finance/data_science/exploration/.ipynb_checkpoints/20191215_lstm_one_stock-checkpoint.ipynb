# %%
import psycopg2
import datetime
import numpy as np
import pandas as pd
from itertools import islice
from sklearn import preprocessing

import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters

import torch
from torch import nn, optim

from finance.utilities import utils
from finance.data_science.utilities import (financial_utils, time_series_utils, 
                                            cluster_utils, random_forest_utils, nn_utils)

# %% [markdown]
# ### Get stock data

# %%
date_start = '2005-01-01'
date_end = '2019-01-01'
query = f"""
    with 
    tickers as (
    select distinct 
        ticker
        , sector
        , industry
    from nasdaq.listed_stocks
    where ticker in ('AA')
    limit 100
    )
    select 
        symbol
        , market_datetime
        , open
    from td.equities as equities
    inner join tickers
        on tickers.ticker = equities.symbol
    where market_datetime > '{date_start}' and market_datetime < '{date_end}'
    order by market_datetime
    """

df = utils.query_db(query=query)
df.head()
# Out:
#   symbol     market_datetime       open
# 0     AA 2005-01-03 06:00:00  95.400000
# 1     AA 2005-01-04 06:00:00  92.670003
# 2     AA 2005-01-05 06:00:00  91.289997
# 3     AA 2005-01-06 06:00:00  91.500003
# 4     AA 2005-01-07 06:00:00  91.260000

# %% [markdown]
# ### Clean data

# %%
plt.plot(df['open'])
plt.show()

# %%
plt.hist(df['open'])
plt.title('Open Histogram')
plt.show()

# %% [markdown]
# ### Lstm on open data

# %%
df['open_min'] = df['open'].rolling(100).min()
df['open_max'] = df['open'].rolling(100).max()

df['target'] = (df['open'] - df['open_min'])/(df['open_max'] - df['open_min'])

df = df[df['target'].notnull()]

# %%
plt.plot(df['target'])
plt.show()

# %%
plt.hist(df['target'])
plt.show()

# %%
x_temp = df['target'].values

sequence_length = 100

x = []
y = []

for n in range(len(x_temp) - sequence_length - 1):
    x_i = x_temp[n : n + sequence_length]
    y_i = x_temp[n + sequence_length]
    
    x.append(x_i)
    y.append(y_i)

x_arr = np.array(x)
y_arr = np.array(y)

print(len(x_arr))
# Out:
# 3323

# %%
model = nn_utils.TorchLSTM(train_x=pd.DataFrame(x_arr).head(1000), 
                           train_y=pd.DataFrame(y_arr).head(1000),
                           test_x=pd.DataFrame(x_arr).tail(1000), 
                           test_y=pd.DataFrame(y_arr).tail(1000),
                           n_layers=2,
                           n_epochs=1000,
                           hidden_shape=1000,
                           batch_size=10,
                           dropout=.1,
                           learning_rate=.0001,
                           device='cuda:0')

# %%
model.execute()
# Out:
# Epoch  0 Error:  506.92724609375
# Epoch  100 Error:  107.86444854736328
# Epoch  200 Error:  70.01598358154297
# Epoch  300 Error:  61.96014404296875
# Epoch  400 Error:  51.43375778198242
# Epoch  500 Error:  47.40996551513672
# Epoch  600 Error:  43.90924072265625
# Epoch  700 Error:  42.895355224609375
# Epoch  800 Error:  42.51091003417969
# Epoch  900 Error:  40.122955322265625

# %%
model.plot_prediction_train()

# %%
model.plot_prediction_test()

# %%
model.reset_network()

# %%
test_df = model.test_df
temp = df.tail(1000).reset_index(drop=True)
test_df = test_df.join(temp)
test_df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.797217  0.819149  0.821277  0.851064  0.804255  0.842553  0.840426
# 1  0.819149  0.821277  0.851064  0.804255  0.842553  0.840426  0.870213
# 2  0.821277  0.851064  0.804255  0.842553  0.840426  0.870213  0.872340
# 3  0.851064  0.804255  0.842553  0.840426  0.870213  0.872340  0.874200
# 4  0.804255  0.842553  0.840426  0.870213  0.872340  0.874200  0.876333
#
#           7         8         9  ...        98        99   actuals  \
# 0  0.870213  0.872340  0.874200  ...  0.357541  0.463687  0.567039
# 1  0.872340  0.874200  0.876333  ...  0.463687  0.567039  0.670391
# 2  0.874200  0.876333  0.884861  ...  0.567039  0.670391  0.689944
# 3  0.876333  0.884861  0.948663  ...  0.670391  0.689944  0.407821
# 4  0.884861  0.948663  0.975056  ...  0.689944  0.407821  0.324022
#
#    prediction  symbol     market_datetime       open   open_min  open_max  \
# 0    0.619120      AA 2015-01-12 06:00:00  49.200003  42.000003     52.74
# 1    0.662580      AA 2015-01-13 06:00:00  49.410000  42.000003     52.74
# 2    0.737045      AA 2015-01-14 06:00:00  46.379997  42.000003     52.74
# 3    0.780688      AA 2015-01-15 06:00:00  45.479997  42.000003     52.74
# 4    0.666197      AA 2015-01-16 06:00:00  44.880003  42.000003     52.74
#
#      target
# 0  0.670391
# 1  0.689944
# 2  0.407821
# 3  0.324022
# 4  0.268156
#
# [5 rows x 108 columns]

# %%
test_df['prediction_mapped'] = (test_df['prediction'] * (test_df['open_max'] - test_df['open_min'])) + test_df['open_min']
test_df['actuals_mapped'] = (test_df['actuals'] * (test_df['open_max'] - test_df['open_min'])) + test_df['open_min']

# %%
test_df[['open', 'prediction_mapped']].head()
# Out:
#         open  prediction_mapped
# 0  49.200003          48.649351
# 1  49.410000          49.116109
# 2  46.379997          49.915865
# 3  45.479997          50.384595
# 4  44.880003          49.154952

# %%
plt.title('$ Prediction v Actual')
plt.plot(test_df['prediction_mapped'], color='r')
plt.plot(test_df['open'])
plt.show()

# %%
plt.title('$ Prediction Errors')
plt.plot(test_df['prediction_mapped']-test_df['open'], color='r')
plt.hlines(0, xmin=test_df.index.min(), xmax=test_df.index.max())
plt.show()

# %%
plt.title('% Prediction Errors')
plot = plt.hist((test_df['prediction_mapped']-test_df['open'])/test_df['open'], bins=45)
plt.vlines(0, ymin=0, ymax=plot[0].max())
plt.show()

# %%
test_df['transaction'] = 'nothing'
test_df['predicted_change'] = test_df['prediction_mapped'].shift(-1) - test_df['open']
test_df.loc[test_df['predicted_change'] > 0, 'transaction'] = 'buy'
test_df.loc[test_df['predicted_change'] < 0, 'transaction'] = 'sell'

test_df[['open', 'prediction_mapped', 'transaction']].tail(20)
# Out:
#       open  prediction_mapped transaction
# 980  31.04          31.448571         buy
# 981  32.90          32.328378        sell
# 982  32.11          32.537853        sell
# 983  29.66          31.841864         buy
# 984  30.15          31.978356        sell
# 985  28.64          29.730002         buy
# 986  29.16          29.689978         buy
# 987  28.89          29.665010         buy
# 988  29.27          29.790246         buy
# 989  28.51          29.924884         buy
# 990  28.50          29.939624         buy
# 991  28.12          30.147743         buy
# 992  28.32          30.894532         buy
# 993  27.66          30.553194         buy
# 994  27.33          30.308425         buy
# 995  26.27          28.559776         buy
# 996  25.31          27.347346         buy
# 997  26.41          27.936469         buy
# 998  27.09          28.491518         buy
# 999  26.75          29.473680     nothing

# %%
plt.title('Predicted changes')
plt.hist(test_df.loc[test_df['predicted_change'].notnull(), 'predicted_change'], bins=35)
plt.show()

# %% [markdown]
# ### Long short with kelly criterion

# %%
def kelly(predicted_win, predicted_loss, p_win, p_loss):
    bet_size = (predicted_win * p_win - predicted_loss * p_loss) / predicted_win
    return bet_size

long = False
short = False
profit_loss = [0]
bet_sizes = []
portfolio_size = 1000

for idx, row in test_df.iterrows():
    if row['transaction'] == 'buy' and short:
        n_shares = int((bet * portfolio_size)/price)
        profit_loss.append(n_shares * (price - row['open']))
        short = False
    elif row['transaction'] == 'sell' and long:
        n_shares = int((bet * portfolio_size)/price)
        profit_loss.append(n_shares * (row['open'] - price))
        long = False
    if not long and not short:
        bet = kelly(abs(row['predicted_change']), np.median(np.abs(profit_loss)), .7, .3)/5
        if bet > 0:
            price = row['open']
            bet_sizes.append(bet)
            if row['transaction'] == 'buy':
                long = True
            elif row['transaction'] == 'sell':
                short = True

annualized_return = (1+sum(profit_loss)/portfolio_size)**(1/(len(test_df)/250))-1
print('Annualized P/L ' + str(round(annualized_return, 6)))

plt.title('Cumulative P/L')
plt.plot(np.cumsum(profit_loss))
plt.show()

plt.title('P/L Over Time')
plt.plot(profit_loss)
plt.hlines(0, xmin=0, xmax=len(profit_loss))
plt.show()

plt.title('P/L Over Time')
plt.hist(profit_loss, bins=25)
plt.show()

plt.title('Bet Sizes')
plt.hist(bet_sizes, bins=25)
plt.show()
# Out:
# Annualized P/L 0.018133

# %%
pl = pd.DataFrame(profit_loss, columns=['profits'])

pl['win'] = 0
pl['loss'] = 0
pl.loc[pl['profits'] > 0, 'win'] = 1
pl.loc[pl['profits'] <= 0, 'loss'] = 1

pl['cumulative_wins'] = pl['win'].cumsum()
pl['cumulative_losses'] = pl['loss'].cumsum()

pl['win_rate'] = pl['cumulative_wins']/(pl['cumulative_wins'] + pl['cumulative_losses'])

plt.title('Win Rate')
plt.plot(pl['win_rate'])
plt.show()

pl.head()
# Out:
#     profits  win  loss  cumulative_wins  cumulative_losses  win_rate
# 0  0.000000    0     1                0                  1      0.00
# 1 -0.419994    0     1                0                  2      0.00
# 2 -2.640006    0     1                0                  3      0.00
# 3  0.689994    1     0                1                  3      0.25
# 4  1.379988    1     0                2                  3      0.40
