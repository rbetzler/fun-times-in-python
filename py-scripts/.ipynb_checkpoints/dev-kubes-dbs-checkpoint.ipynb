# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Wed Jan 30 23:02:27 2019

@author: nautilus
"""

#Import py functions
import sys
import psycopg2
import datetime
import pandas as pd
import multiprocessing as mp
from sqlalchemy import create_engine

# %%
#Grab tickers
conn_string = "host='10.152.183.137' dbname='dw_stocks' user='dbadmin' password='password' port='5432'"
conn = psycopg2.connect(conn_string)
cursor = conn.cursor()
query = 'select * from temp_test;'

# %%
cursor.execute(query)
for row in cursor:
    print(row)
# Out:
# ('test',)
# ('test more',)

# %%
from pymongo import MongoClient
client = MongoClient()

# %%
#client = MongoClient('10.152.183.130', 27017)
client = MongoClient('10.152.183.130', 32365)

# %%
print(client.list_database_names())
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <ipython-input-16-2197b31e233e> in <module>
# ----> 1 print(client.list_database_names())
#
# ~/anaconda3/envs/babylon/lib/python3.6/site-packages/pymongo/mongo_client.py in list_database_names(self, session)
#    1662         """
#    1663         return [doc["name"]
# -> 1664                 for doc in self.list_databases(session, nameOnly=True)]
#    1665
#    1666     def database_names(self, session=None):
#
# ~/anaconda3/envs/babylon/lib/python3.6/site-packages/pymongo/mongo_client.py in list_databases(self, session, **kwargs)
#    1643         cmd.update(kwargs)
#    1644         admin = self._database_default_options("admin")
# -> 1645         res = admin.command(cmd, session=session)
#    1646         # listDatabases doesn't return a cursor (yet). Fake one.
#    1647         cursor = {
#
# ...
